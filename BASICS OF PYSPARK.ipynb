# %%
# %sql
CREATE DATABASE development.data
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-5856247280677553>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'CREATE DATABASE development.data\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:213, in SqlMagic.sql(self, line, cell)
#     206 except BaseException as e:
# ...

# %%
# %sql
CREATE  VOLUME development.data.files
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-5856247280677555>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'CREATE VOLUME development.data.files\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:213, in SqlMagic.sql(self, line, cell)
#     206 except BaseException as e:
# ...

# %% [markdown]
# **DATAFRAME** **PRACTICAL**

# %%
df = spark.read.csv('/Volumes/development/data/files/orders/orders.csv', header= True, inferSchema=True)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
 df.show()
# Out:
# +--------------+----------+----------+--------------+-----------+-------+---------------+---------------+------+--------+------+
# |      order_id|order_date| ship_date|     ship_mode|customer_id| region|     product_id|       category| sales|quantity|profit|
# +--------------+----------+----------+--------------+-----------+-------+---------------+---------------+------+--------+------+
# |CA-2020-152156|2020-11-08|2020-11-11|  Second Class|   CG-12520|  South|FUR-BO-10001798|      Furniture| 262.0|       2|  41.9|
# |CA-2020-152156|2020-11-08|2020-11-11|  Second Class|   CG-12520|  South|FUR-CH-10000454|      Furniture| 731.9|       3| 219.6|
# |CA-2020-138688|2020-06-12|2020-06-16|  Second Class|   DV-13045|   West|OFF-LA-10000240|Office Supplies|  14.6|       2|   6.9|
# |US-2019-108966|2019-10-11|2019-10-18|Standard Class|   SO-20335|  South|FUR-TA-10000577|      Furniture| 957.6|       5|-383.0|
# ...

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- ship_date: date (nullable = true)
#  |-- ship_mode: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- sales: double (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- profit: double (nullable = true)

# %% [markdown]
# **SELECT TRANSFORMATION**

# %%
display(df.select('order_date', 'profit', 'order_id', ))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display((df.select(df.category, df.customer_id, df.region )))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import * 
df.select(col("order_id"), col("order_date"), col("profit").alias("Pofit we collect")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# **withColumn & withColumnRenameda**

# %%
from pyspark.sql.functions import * 
display(df.withColumn("new profit",col("profit")*100))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
