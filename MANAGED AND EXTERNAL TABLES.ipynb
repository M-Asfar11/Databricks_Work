# %% [markdown]
# **Managed** **Table**

# %%
# %sql
create table data_dev.default.test(
id int, 
name string
)
using delta

# %%
# %sql
insert into data_dev.default.test values (1, 'asfar')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
select * from data_dev.default.test;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th></tr></thead><tbody><tr><td>1</td><td>asfar</td></tr></tbody></table></div>

# %% [markdown]
# **External Table**

# %%
# %sql
# CREATE TABLE data_dev.default.external_table
# ( id int, 
#     name VARCHAR(20)
# )
# USING delta 
# LOCATION "" --your eternal path
