# %% [markdown]
# **MANAGED VOLUME**

# %%
# %sql
CREATE VOLUME data_dev.default.practical

# %%
# %sql
DROP VOLUME data_dev.default.practical

# %% [markdown]
# **EXTERNAL VOLUME**

# %%
# %sql
# CREATE EXTERNAL VOLUME data_dev.default.external_volume 
# LOCATION 'dbfs:/FileStore/shared_uploads/external_volume'

# %%
# %sql
# DROP EXTERNAL VOLUME  data_dev.default.external_volume
